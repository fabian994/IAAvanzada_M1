# %% [markdown]
# # Workshop 2
# Fabián González Vera A01367585
# 16/08/2023

# %% [markdown]
# ## 2 The Central Limit Theorem

# %% [markdown]
# 2.2 Monte Carlo simulation

# %%
from symbulate import *
#'exec(%matplotlib inline)' 
import matplotlib
import matplotlib.pyplot as plt

# %%
# clear the plot space:
plt.clf()
# Define the probability type of function as uniform (probability space)
P = Uniform(0,40)
# Define X as a random variable of the type P (uniform)
X =RV(P)
# Simulate the values of X and save the in the x array: 
x=X.sim(10000)
x.plot()
plt.show()

# %% [markdown]
# ## 2.2.2 CHALLENGE
#
#       A. CALCULATE THE MEAN AND STANDARD DEVIATION OF THIS SIMULATED UNIFORM x VARIABLE. HOW CLOSE WERE THESE MEAN AND STANDARD DEVIATION FROM THE THEORETICAL MEAN AND STANDARD DEVIATION?
#
#       B. INTERPET THE ABOVE HISTOGRAM. WHAT DO YOU SEE? EXPLAIN WITH YOUR WORDS.

# %%
# A
# MEAN and STD
x_mean = x.mean()
x_std = x.std()
print("Mean of x: ", x_mean)
print("STD of x : ", x_std)

# The theoretical mean is 20 and the theoretical std is 11.54, There is a small difference due to decimals
# Out:
# Mean of x:  20.030300107989593
# STD of x :  11.624126913871617

# %% [markdown]
# B.
# THE SIMULATED VALUES OF x ARE ABOVE THE VALUE OF 0.020

# %%
# Define the probability space as a vector of 25 uniform random numbers:
P = Uniform(0,40) ** 25
# Define XVECTOR as a vector of random variables with 25 random values 
XVECTOR =RV(P)
# Simulate 10,000 vectors to get a matrix  
xmatrix=XVECTOR.sim(10000)
xmatrix
# Out:
# Index Result
# 0     (8.917737777064634, 14.845212624166813, 4.68422809394017, 5.057897501516626, 19.626921660348554, ..., 23.557068648297587)
# 1     (38.7236553117778, 11.74438661063669, 12.010264390185945, 6.207347830393695, 37.343180550974935, ..., 20.69989019664268)
# 2     (19.063958618906586, 0.12226424966836902, 12.518658355453844, 10.48060523233958, 17.773308757849897, ..., 10.220407604109742)
# 3     (4.230328939669574, 1.6991106344524942, 27.900291748664085, 0.9425722244354873, 25.802548713648797, ..., 34.19438923699118)
# 4     (14.215483312987987, 35.01972505910907, 26.438866482042034, 29.533636953827642, 0.44415498622000893, ..., 35.886476839095685)
# 5     (2.2711903636979303, 29.126421901225854, 10.380820528471961, 4.723879003283549, 38.28676839391327, ..., 17.19130222000661)
# 6     (25.290440827016457, 5.263156555803135, 24.53563598374724, 7.903855056063285, 5.090505091951014, ..., 19.728701627860662)
# 7     (17.478525554053412, 2.5099414401443987, 12.664145321513335, 15.358986954540889, 17.16519630734296, ..., 39.61907184738269)
# 8     (1.9412294264041918, 14.832201691335381, 38.38136160638852, 5.977052311467768, 17.95179991657774, ..., 30.476275423004)
# ....  ........................................................................................................................
# 9999  (26.0426709212873, 31.512436864518477, 36.35185430869153, 7.770091150605176, 13.124187252176993, ..., 14.72487533204692)

# %%
# The 2nd parameter is the mathematical operation applied to each row of the random vector
# Simulate 10,000 means of each random vector of 25 uniform distributed numbers: 
xmean = RV(P,mean).sim(10000)
xmean
# Out:
# Index Result
# 0     20.19636471753406
# 1     21.15683340775548
# 2     16.37968124829328
# 3     22.61276477858153
# 4     16.56079627692769
# 5     21.607522734136136
# 6     21.634758947288727
# 7     17.141812962770395
# 8     21.007178167015713
# ....  .................
# 9999  24.72453588116731

# %%
plt.clf()
xmean.plot()
plt.show()

# %% [markdown]
# ## 2.2.3 CHALLENGE
#
#     A. CALCULATE THE MEAN AND STANDARD DEVIATION OF THE xmean VARIABLE. HOW SIMILAR OR DIFFERENT ARE THESE VALUES FROM THE MEAN AND STANDARD DEVIATION OF x?
#
#     B. WHAT DO YOU SEE IN THE ABOVE HISTOGRAM? DOES THE HISTOGRAM OF SAMPLE MEANS OF UNIFORM RANDOM VARIABLE LOOK LIKE A UNIFORM DISTRIBUTED VARIABLE? DO YOU SEE A LOGIC? BRIEFLY EXPLAIN WHAT YOU THINK.

# %%
# A
# MEAN and STD
xmean_mean = xmean.mean()
xmean_std = xmean.std()
print("Mean of x: ", xmean_mean)
print("STD of x : ", xmean_std)
# Out:
# Mean of x:  19.971525781175487
# STD of x :  2.3188666144580736

# %% [markdown]
# B.
# THE VALUES AROUND 20 HAVE A GREATER CHANCE TO APPEAR, THE RANGE OF VALUES HAS REDUCED, THE VARIABILITY OF THE VALUES HAS REDUCED DUE TO THE VALUES COMO FROM THE AVERAGE OF A GROUP OF VALUES

# %%
plt.clf()
xmean.plot()
x.plot()
plt.show()

# %% [markdown]
# C. WHAT DO YOU SEE? HOW THE HISTOGRAM OF X DIFFERS FROM THE HISTOGRAM OF THE SAMPLES OF X?
#
# THE MAIN DIFFERENCE IS THE RANGE OF THE VALUES OF X, THIS ALSO MEANS THAT WITH THE NUMBER OF REDUCED VALUES, SOME VALUES HAVE A GREATER FRECUENCY

# %% [markdown]
# ## 2.2.4 Simulating numbers with the NORMAL probability distribution
# Let’s simulate a normal distributed variable Y with mean = 20 and standard devation = 10.

# %%
# clear the plot space:
plt.clf()
# Define the probability type of function as uniform (probability space)
P = Normal(mean=20, sd=10)
# Define Y as a random variable of the type P (normal)
Y =RV(P)
# Simulate 10,000 values of Y and save the in the x array: 
y=Y.sim(10000)
y.plot()
plt.show()

# %% [markdown]
# ## 2.2.5 CHALLENGE
#
# A. CALCULATE THE MEAN AND STANDARD DEVIATION OF THIS RANDOM y VARIABLE. HOW SIMILAR OR DIFFERENT ARE THESE VALUES FROM THE MEAN AND STANDARD DEVIATION OF THE THEORETICAL MEAN (20) AND THE THEORETICAL STANDARD DEVIATION (10)?
#
# B. WHAT DO YOU SEE? INTERPRET THE HISTOGRAM WITH YOUR WORDS

# %%
# A.
print("Mean of y: ", y.mean())
print("STD of y : ", y.std())
# THERE´S NOT MUCH DIFFERENCE BETWEEN THE VALUES OF THE MEAN AND STD OF y AND THE THEORETICAL MEAN AND STD
# Out:
# Mean of y:  20.067341671277774
# STD of y :  9.96821095955202

# %% [markdown]
# B.

# %%
# Define the probability space P as a vector of 25 normal random numbers:
P = Normal(mean=20, sd=10) ** 25
# Define RANDOMVECTOR as a vector of 25 random variables in the Probability space P 
RANDOMVECTOR = RV(P)
# Simulate 10,000 random vectors with this distribution and save the in ymatrix: 
ymatrix=RANDOMVECTOR.sim(10000)
ymatrix
# Out:
# Index Result
# 0     (20.394209679225884, 46.282606416294946, 14.562862232900656, 2.5525320597385637, 5.920712789194331, ..., 27.788541490787992)
# 1     (25.332963430412327, 40.82627326129429, 25.42351518753362, 33.75356111977099, 3.6342277675717796, ..., 32.872949927563866)
# 2     (17.246710155722845, 28.153323950454915, 8.306120126902998, 23.495828857277118, 33.45535212142104, ..., 24.066901892204786)
# 3     (29.704420493616055, 12.577696232526616, 40.33969104464178, 28.956011478766236, 19.728050358663193, ..., 30.806611041667534)
# 4     (17.308680667513357, 12.284314321973309, 28.907028788495616, 9.363751640298005, 12.423108509866609, ..., 4.514161097508019)
# 5     (21.522608110739675, 23.660593966634334, 11.331780644617073, 27.69617941084654, 34.03477314865529, ..., 24.91958183172445)
# 6     (17.95915131488616, 16.822797072009486, 10.925558356796433, 20.92605415763728, 7.5186801520787565, ..., 16.525961099271804)
# 7     (22.266187909305447, 22.12804753713959, 26.90322473694035, 30.815884769319275, 26.229284164134004, ..., 15.389882951049803)
# 8     (13.011998472828914, 8.012975574935684, 13.88680616469428, 17.97023880480581, 23.95278670219495, ..., 13.904175615204863)
# ....  ..........................................................................................................................
# 9999  (25.95855748483472, 34.443269888598614, 39.75330134838343, 31.943979841740134, 16.90116942842916, ..., 21.044154629635855)

# %%
# The 2nd parameter is the mathematical operation applied to each row of the random vector
# Simulate 10,000 means of each random vector of 25 uniform distributed numbers: 
ymean = RV(P,mean).sim(10000)
ymean
# Out:
# Index Result
# 0     20.861522695961607
# 1     16.157274742008475
# 2     19.66380176963547
# 3     19.48376187284009
# 4     17.926872558542254
# 5     18.802151199599795
# 6     22.084347631428447
# 7     26.455771917349253
# 8     17.47310485345705
# ....  .................
# 9999  23.89124051478666

# %%
plt.clf()
ymean.plot()
plt.show()

# %% [markdown]
# ## 2.2.6 CHALLENGE
#
#     A. CALCULATE THE MEAN AND STANDARD DEVIATION OF THE ymean VARIABLE. HOW SIMILAR OR DIFFERENT ARE THESE VALUES FROM THE MEAN AND STANDARD DEVIATION OF y?
#
#     B. INTERPRET THE ABOVE HISTOGRAM OF THE SAMPLES OF y.
#
# Now plot both histograms, the histogram of y and the histogram of ymean:

# %%
plt.clf()
ymean.plot()
y.plot()
plt.show()

# %%
ymean.std()
# Out:
# 1.9749111867625657

# %% [markdown]
# B. WHAT DO YOU SEE? COMPARE BOTH HISTOGRAMS. BRIEFLY EXPLAIN WHAT YOU THINK THAT HAPPEND.

# %% [markdown]
# THE VARIANCE AND THE FREQUENCY BETWEEN THE 2 HISTOGRAMS IS VERY DIFFERENT, DUE TO THE FACT THAT ymean IS MADE OF THE AVERAGE OF GROUPS AND y IS MADE OF ONLY ONE VALUE

# %% [markdown]
# ## 4.1 CHALLENGE
# Collect real data for Microsoft (MSFT) stock and do a hypothesis testing to see whether the mean of monthly cc returns of Microsoft is greater than zero.
#
# You have to do the following:
#
# Run a t-test to compare whether the mean return of MSFT is greater than zero.
#
# To do a hypothesis test, we usually do the following steps:
#
#     A.DEFINE THE VARIABLE OF STUDY. In this case it will be the mean of MSFT cc returns
#
#     B.WRITE THE NULL AND THE ALTERNATIVE HYPOTHESIS.
#
#     C.CALCULATE THE STANDARD ERROR, WHICH IS THE STANDARD DEVIATION OF THE VARIABLE OF STUDY.
#
#     D.CALCULATE THE t-statistic (t-value). EXPLAIN/INTERPRET THE t-statistic.
#
#     E.CALCULATE THE 95% CONFIDENCE INTERVAL OF THE SAMPLE MEAN
#
#     F.WRITE YOUR CONCLUSION OF THE t-TEST

# %%
import yfinance as yf

# %%
MSTF=yf.download(tickers="MSFT", start="2017-01-01",interval="1mo")
MSTF
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-01   62.790001   65.910004   61.950001   64.650002   59.148548
# 2017-02-01   64.360001   65.239998   62.750000   63.980000   58.535564
# 2017-03-01   64.129997   66.190002   63.619999   65.860001   60.620876
# 2017-04-01   65.809998   69.139999   64.849998   68.459999   63.014069
# 2017-05-01   68.680000   70.739998   67.139999   69.839996   64.284279
# ...                ...         ...         ...         ...         ...
# 2023-04-01  286.519989  308.929993  275.369995  307.260010  305.942047
# 2023-05-01  306.970001  335.940002  303.399994  328.390015  326.981384
# 2023-06-01  325.929993  351.470001  322.500000  340.540009  339.820526
# 2023-07-01  339.190002  366.779999  327.000000  335.920013  335.210297
# 2023-08-01  335.190002  338.540009  318.690002  319.540009  319.540009
#
#                Volume
# Date
# 2017-01-01  493453500
# 2017-02-01  440744000
# 2017-03-01  489169700
# 2017-04-01  433191200
# 2017-05-01  517218500
# ...               ...
# 2023-04-01  551497100
# 2023-05-01  600807200
# 2023-06-01  547588700
# 2023-07-01  666764400
# 2023-08-01  260320072
#
# [80 rows x 6 columns]

# %%
MSTF["R"] = (MSTF["Adj Close"] / MSTF["Adj Close"].shift(1)) - 1
print(MSTF["R"])
# Out:
# Date
# 2017-01-01         NaN
# 2017-02-01   -0.010363
# 2017-03-01    0.035625
# 2017-04-01    0.039478
# 2017-05-01    0.020158
#                 ...
# 2023-04-01    0.065765
# 2023-05-01    0.068769
# 2023-06-01    0.039266
# 2023-07-01   -0.013567
# 2023-08-01   -0.046748
# Name: R, Length: 80, dtype: float64

# %%
MSTF["r"] = np.log(MSTF['Adj Close']) - np.log(MSTF['Adj Close'].shift(1))
# Another way to do the same as above is appying the diff method to the log:  
MSTF["r2"] = np.log(MSTF['Adj Close']).diff(1)

# We can see that r and r2 are the same: 
print(MSTF.tail())

# I keep a new object with only returns:
MSTFR = MSTF[['R','r']].copy()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-04-01  286.519989  308.929993  275.369995  307.260010  305.942047
# 2023-05-01  306.970001  335.940002  303.399994  328.390015  326.981384
# 2023-06-01  325.929993  351.470001  322.500000  340.540009  339.820526
# 2023-07-01  339.190002  366.779999  327.000000  335.920013  335.210297
# 2023-08-01  335.190002  338.540009  318.690002  319.540009  319.540009
#
#                Volume         R         r        r2
# Date
# 2023-04-01  551497100  0.065765  0.063693  0.063693
# 2023-05-01  600807200  0.068769  0.066508  0.066508
# 2023-06-01  547588700  0.039266  0.038514  0.038514
# 2023-07-01  666764400 -0.013567 -0.013660 -0.013660
# 2023-08-01  260320072 -0.046748 -0.047876 -0.047876

# %%
# A. The Variable of Study
MSTFR = MSTFR.dropna()
MSTFR = MSTFR['r']
MSTFR
# Out:
# Date
# 2017-02-01   -0.010418
# 2017-03-01    0.035005
# 2017-04-01    0.038719
# 2017-05-01    0.019957
# 2017-06-01   -0.007400
#                 ...
# 2023-04-01    0.063693
# 2023-05-01    0.066508
# 2023-06-01    0.038514
# 2023-07-01   -0.013660
# 2023-08-01   -0.047876
# Name: r, Length: 79, dtype: float64

# %%
plt.hist(MSTFR,bins=12, alpha=0.5)
plt.title("Histogram of MSTF cc returns")
plt.show()

# %% [markdown]
# B. The hypothesis are:
#
# H0: MSTF cc returns are smaller than 0, x < 0
#
# Ha: MSTF cc returns are greater than 0, x > 0

# %%
# C. Standard Error
MSTFre = MSTFR.std()
print(MSTFre)
st_e = (MSTFre)/sqrt(len(MSTFR))
st_e
# Out:
# 0.05791370491923639
# 0.0065158008702432815

# %%
# D. t-value

t_val = (MSTFR.mean()- 0)/st_e
t_val
# Out:
# 3.2770007132659855

# %%
# E. 95% CONFIDENCE INTERVAL

coIN95_upperVal = MSTFR.mean() + 1.960 * (st_e/len(MSTFR))
coIN95_lowerVal = MSTFR.mean() - 1.960 * (st_e/len(MSTFR))
print(coIN95_upperVal)
print(coIN95_lowerVal)
# Out:
# 0.02151394194366202
# 0.021190626254910708

# %% [markdown]
# F.
